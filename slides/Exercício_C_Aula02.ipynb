# %% [markdown]
# ## Exemplo 3 - Geocodificação e Rotas
#
# Nessa seção, vamos usar o OpenStreetMap para fazer a geocodificação de dois pontos e a criação de uma rota entre eles.
#
# Para criar um usuário no OpenStreetMap:
# https://www.openstreetmap.org
#
# Para criar um usuário (e token) no OpenRouteServices:
# https://openrouteservice.org/

# %%
# Preparando o ambiente no Google Drive:

#importando a biblioteca
from google.colab import drive

# Isso irá pedir sua autorização
drive.mount('/content/drive')

# Agora, seu Drive estará disponível em: /content/drive/My Drive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#instalando a biblioteca
# !pip install openrouteservice ortools

# %%
from geopy.geocoders import Nominatim
import folium
from openrouteservice import client

#estilo da rota
style = {'color': '#FF0000'}

# API do openroute services
api_key = '5b3ce3597851110001cf62482120dcda4a2c487180d75a62b6115c3d'
clnt = client.Client(key=api_key) # Create client with api key

# Pede e geocodifica os dois endereços
geolocator = Nominatim (user_agent = 'silvanacamboim@gmail.com')
endereco = input ("Entre com o primeiro endreco: ")
location = geolocator.geocode (endereco)

endereco1 = input ("Entre com o segundo endreco: ")
location1 = geolocator.geocode (endereco1)

#Coloca os pois pontos no mapa
m = folium.Map (location= [location.latitude, location.longitude],zoom_start=14)
folium. Marker (location=[location.latitude, location.longitude], popup=endereco,
                 icon=folium.Icon(color='blue',icon='star')).add_to (m)
folium. Marker (location=[location1.latitude, location1.longitude], popup=endereco,
                 icon=folium.Icon(color='red',icon='star')).add_to (m)

# Requisição da Rota

request_params = {'coordinates': [[location.longitude, location.latitude],
                                 [location1.longitude, location1.latitude]],
                'format_out': 'geojson',
                'profile': 'driving-car',
                'preference': 'shortest',
                'instructions': 'false',}
route_normal = clnt.directions(**request_params)

#Adiciona a rota no mapa
folium.features.GeoJson(data=route_normal,
                        name='Rota entre os pontos',
                        style_function=lambda x: style,
                        overlay=True).add_to(m)
m

# %% [markdown]
# # Agora é sua vez!
# <img src="https://image.flaticon.com/icons/svg/1508/1508880.svg" width=150px >
#
# ## Exercício 3
#
#
# 1.   Faça seu próprio geocodificador, com estilos, chaves e usuários próprios.
