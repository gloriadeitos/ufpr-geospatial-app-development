# %% [markdown]
# <a href="https://colab.research.google.com/github/gloriadeitos/ufpr-geospatial-app-development/blob/main/lesson_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises / Exercícios

# %% [markdown]
# **Student / Aluna:** Glória Maria Deitos Gomes da Silva
#
# **Date /  Data:** 02/02/2026
#
# **Exemplos para realizar os exercícios da aula 01:** https://drive.google.com/file/d/1ObBkIYiBgQotFLVMtljZGN-SvlTHUsc4/view
#
# **GitHub:** https://github.com/gloriadeitos/ufpr-geospatial-app-development

# %% [markdown]
# ## Exercise 1 / Exercício 1
#
# **EN:** Display the current date in the format mm/dd/yyyy. Display the current time in the format hh:mm:ss.
#
# **PT:** Exiba a data atual na forma mm/dd/yyyy. Exiba a hora atual no formato hh:mm:ss.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 2 / Exercício 2
#
# **EN:** Create a function that transforms sexagesimal latitude and longitude into decimal and vice versa.
#
# **PT:** Crie uma função que transforme latitude e longitude sexagesimais em decimais e vice-versa.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 3 / Exercício 3
#
# **EN:** Create a dictionary for five students. The name of the dictionary must be the student's first name.
#
# **PT:** Crie o dicionário de cinco alunos. O nome do dicionário deve ser o primeiro nome do aluno.

# %% [markdown]
# **a)**
#
# **EN:** Each dictionary has 5 keys; the first two will be strings and the last 3 will be lists of grades: “Name”, “Code”, “Tests”, “Exercises”, and “Assignments”.
#
# **PT:** Cada dicionário tem 5 chaves, as duas primeiras terão strings e as 3 últimas, listas de notas: “Nome”, “Codigo”, “Provas”, “Exercicios” e “Trabalhos”.

# %% [markdown]
# **b)**
#
# **EN:** Fill in for each student: Name, Code, grades for 3 tests, 2 assignments, and 5 exercises.
#
# **PT:** Preencher para cada aluno: Nome, Código, Nota de 3 provas, 2 trabalhos e 5 exercícios.

# %% [markdown]
# **c)**
#
# **EN:** Create a list with the 5 dictionaries combined.
#
# **PT:** Faça uma lista com os 5 dicionários reunidos.

# %% [markdown]
# **d)**
#
# **EN:** Create a function that calculates the average of grades.
#
# **PT:** Crie uma função que calcule média de notas.

# %% [markdown]
# **e)**
#
# **EN:** Calculate the final average for each student. The test has a weight of 5, assignments 4, and exercises 1.
#
# **PT:** Calcule a média final de cada aluno. A prova tem peso 5, os trabalhos 4 e os exercícios 1.

# %% [markdown]
# **f)**
#
# **EN:** Display the student's name, code, and evaluation: Passed for grades above 70; Final Exam for grades between 50 and 70; and Failed for the rest.
#
# **PT:** Exiba o nome do aluno, seu código e sua avaliação: Aprovado para nota acima de 70; Exame final entre 50 e 70; e reprovado para os demais.

# %% [markdown]
# **g)**
#
# **EN:** Calculate the overall class average.
#
# **PT:** Calcule a média geral da turma.

# %% [markdown]
# ---

# %% [markdown]
# # Section 1: Basic Logic / Lógica Básica

# %% [markdown]
# ## 01.01 Exercise / Exercício:
#
# **EN:** Define a function is_int that takes a number x as input. Make it return True if the number is an integer and False otherwise.
#
# **PT:** Defina uma função is_int que tome um número x como entrada. Faça-a retornar True se o número for um inteiro e False caso contrário.

# %% [markdown]
# ## 01.02 Exercise / Exercício:
#
# **EN:** Define a function factorial that takes an integer x as input. Calculate and return the factorial of that number.
#
# **PT:** Defina uma função factorial que toma um número inteiro x como entrada. Calcule e retorne o fatorial daquele número.

# %% [markdown]
# ## 01.03 Exercise / Exercício:
#
# **EN:** Define a function called isnot_prime that takes a number x as input. If it is prime, return False. If it is not prime, return True.
#
# **PT:** Defina uma função chamada isnot_prime que toma um número x como entrada. Se for primo, retorne False. Se não for primo, retorne True.

# %% [markdown]
# ## 01.04 Exercise / Exercício:
#
# **EN:** Define a function called anti_vowel that takes a string, text, as input and returns the text with all vowels removed. Make sure to remove both lowercase and uppercase vowels.
#
# **PT:** Defina uma função chamada anti_vowel que toma uma string, texto, como entrada e retorna o texto com todas as vogais removidas. Tenha certeza de remover as vogais minúsculas e maiúsculas.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2: String & List Manipulation / Manipulação de Strings e Listas

# %% [markdown]
# ## 02.01 Exercise / Exercício:
#
# **EN:** Write a function called censor that takes two strings, text and word, as input. It should return the text with the chosen word replaced by asterisks. Assume input strings contain no punctuation or uppercase letters. The number of asterisks must match the number of letters in the censored word.
#
# **PT:** Escreva uma função chamada censor que toma duas strings, text e word, como entrada. Ela deve retornar o texto com a palavra escolhida substituída por asteriscos. Suponha que as strings de entrada não contêm pontuação ou letras maiúsculas. O número de asteriscos deve corresponder ao número de letras na palavra censurada.

# %% [markdown]
# ## 02.02 Exercise / Exercício:
#
# **EN:** Write a function remove_duplicates that takes a list and removes duplicate elements. Keep a single occurrence of each number. Do not modify the input list; instead, return a new list.
#
# **PT:** Escreva uma função remove_duplicates que toma uma lista e remove elementos duplicados. Mantenha uma única ocorrência de cada número. Não modifique a lista de entrada; em vez disso, retorne uma nova lista.

# %% [markdown]
# ## 02.03 Exercise / Exercício:
#
# **EN:** Write a function called median that takes a list as input and returns the median value. If the list has an even number of elements, return the average of the two middle elements.
#
# **PT:** Escreva uma função chamada median que tome uma lista como entrada e retorne o valor da mediana. Se a lista contiver um número par de elementos, sua função deve retornar a média dos dois elementos do meio.

# %% [markdown]
# ---

# %% [markdown]
# # Section 3: Filtering & Matrices / Filtragem e Matrizes

# %% [markdown]
# ## 03.01 Exercise / Exercício:
#
# **EN:** Create a list consisting only of numbers between 1 and 30 (inclusive) that are divisible by 3 or 5.
#
# **PT:** Crie uma lista que consiste apenas dos números entre 1 e 30 (inclusive) que são divisíveis por 3 ou 5.

# %% [markdown]
# # 03.02 Exercise / Exercício:
#
# **EN:** Create a list that starts at 100 and counts backward by 10s down to zero.
#
# **PT:** Crie uma lista que comece em 100 e conte ao contrário de 10 em 10 até zero.

# %% [markdown]
# ## 03.03 Exercise / Exercício:
#
# **EN:** Use a lambda expression to filter the string "IXXX aXXmX aXXXnXoXXXXXtXhXeXXXXrX sXXXXeXcXXXrXeXt mXXeXsXXXsXaXXXXXXgXeX!XX". Remove all "X" letters to reveal the final message.
#
# **PT:** Filtre com uma expressão lambda a string "IXXX aXXmX aXXXnXoXXXXXtXhXeXXXXrX sXXXXeXcXXXrXeXt mXXeXsXXXsXaXXXXXXgXeX!XX". É preciso retirar as letras X para chegar à expressão final.

# %% [markdown]
# ## 03.04 Exercise / Exercício:
#
# **EN:** Given a 3x3 square matrix A: 1) Display the matrix line by line. 2) Create a function to calculate the transpose of A. 3) Create a function to verify if A is an Identity matrix. 4) Given another matrix B, calculate A + B.
#
# **PT:** Dada uma matriz quadrada A (3x3): 1) Mostrar no console a matriz, linha a linha. 2) Criar uma função que calcule a transposta de A. 3) Criar uma função que verifique se A é igual à identidade. 4) Dada outra matriz B, calcular A + B.

# %% [markdown]
# ---

# %% [markdown]
# # Section 4: Object-Oriented Programming (OOP) / Programação Orientada a Objetos

# %% [markdown]
# ## Exercise / Exercício:
#
# **EN:**
# **Create a Bank Account class:**
# Upon creation, there are no transactions and the balance is zero.
# * To create an account, the owner's name and opening date must be provided.
# Create withdraw and deposit functions. The withdraw function cannot allow a negative balance.
# * Create a function that returns the number of transactions performed and the current balance.
# * Create a SpecialAccount subclass that inherits from Account but includes a credit limit. This account allows withdrawals within the limit.
# * Create accounts and transactions to test the logic.
#
# **PT:**
# **Crie uma classe Conta:**
# * Ao criar uma conta, não há nenhuma transação e o saldo é zero.
# * Para criar uma conta, é preciso informar o nome do proprietário e a data de abertura
# * Crie as funções sacar e depositar. A função sacar não pode permitir saldo negativo.
# * Crie uma função que retorne o número de transações efetuadas e o saldo.
# * Crie uma subclasse ContaEspecial que herde de Conta, mas tenha um limite. Permita saques dentro desse limite.
# * Crie contas e transações para testar a classe.
